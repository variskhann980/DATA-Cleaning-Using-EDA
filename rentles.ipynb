# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns 

df = pd.read_csv('rentals.csv')

df
# Out:
#             id date_listed              community            zone       lat  \
# 0      R000001  2024-12-20            Town Square          Nshama  25.02906
# 1      R000002  2021-07-06              Expo City     Dubai South  24.96152
# 2      R000003  2023-05-10          Palm Jumeirah   Palm Jumeirah  25.10836
# 3      R000004  2021-12-30                  Deira           Deira  25.28720
# 4      R000005  2023-12-08              The Views      The Greens  25.08438
# ...        ...         ...                    ...             ...       ...
# 24995  R024996  2023-02-19              Expo City     Dubai South  24.97266
# 24996  R024997  2023-04-01  Dubai Investment Park             DIP  25.00383
# 24997  R024998  2024-05-26         Emirates Hills  Emirates Hills  25.04242
# 24998  R024999  2026-02-21                 La Mer        Jumeirah  25.22381
# 24999  R025000  2025-10-10         Living Legends       Dubailand  25.08047
#
# ...

# %%
df.head()
# Out:
#         id date_listed      community           zone       lat       lon  \
# 0  R000001  2024-12-20    Town Square         Nshama  25.02906  55.25610
# 1  R000002  2021-07-06      Expo City    Dubai South  24.96152  55.15759
# 2  R000003  2023-05-10  Palm Jumeirah  Palm Jumeirah  25.10836  55.13304
# 3  R000004  2021-12-30          Deira          Deira  25.28720  55.30205
# 4  R000005  2023-12-08      The Views     The Greens  25.08438  55.18399
#
#   property_category property_type  bedrooms  area_sqft  ...  parking_spaces  \
# 0         apartment           1BR         1        748  ...               1
# 1         apartment           1BR         1       1011  ...               2
# 2         apartment           1BR         1        825  ...               2
# 3         apartment           1BR         1        755  ...               1
# 4         apartment           1BR         1        746  ...               1
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  25000 non-null  str
#  1   date_listed         25000 non-null  str
#  2   community           25000 non-null  str
#  3   zone                25000 non-null  str
#  4   lat                 25000 non-null  float64
#  5   lon                 25000 non-null  float64
#  6   property_category   25000 non-null  str
#  7   property_type       25000 non-null  str
#  8   bedrooms            25000 non-null  int64
#  9   area_sqft           25000 non-null  int64
#  10  area_m2             25000 non-null  float64
#  11  view                25000 non-null  str
#  12  furnishing          25000 non-null  str
#  13  chiller_included    25000 non-null  bool
#  14  parking_spaces      25000 non-null  int64
#  15  metro_station       25000 non-null  str
# ...

# %%
df.isna()
# Out:
#           id  date_listed  community   zone    lat    lon  property_category  \
# 0      False        False      False  False  False  False              False
# 1      False        False      False  False  False  False              False
# 2      False        False      False  False  False  False              False
# 3      False        False      False  False  False  False              False
# 4      False        False      False  False  False  False              False
# ...      ...          ...        ...    ...    ...    ...                ...
# 24995  False        False      False  False  False  False              False
# 24996  False        False      False  False  False  False              False
# 24997  False        False      False  False  False  False              False
# 24998  False        False      False  False  False  False              False
# 24999  False        False      False  False  False  False              False
#
# ...

# %%
df.tail()
# Out:
#             id date_listed              community            zone       lat  \
# 24995  R024996  2023-02-19              Expo City     Dubai South  24.97266
# 24996  R024997  2023-04-01  Dubai Investment Park             DIP  25.00383
# 24997  R024998  2024-05-26         Emirates Hills  Emirates Hills  25.04242
# 24998  R024999  2026-02-21                 La Mer        Jumeirah  25.22381
# 24999  R025000  2025-10-10         Living Legends       Dubailand  25.08047
#
#             lon property_category property_type  bedrooms  area_sqft  ...  \
# 24995  55.13237         apartment           2BR         2       1283  ...
# 24996  55.18909         apartment        studio         0        347  ...
# 24997  55.15843             villa     4BR_villa         4       3265  ...
# 24998  55.26591             villa     4BR_villa         4       3625  ...
# 24999  55.29660         apartment           2BR         2       1130  ...
#
# ...

# %%
plt.plot(df['bedrooms'] , df['area_m2'])

# %%
plt.subplot(2,2,1)
plt.plot(df['metro_distance_min'] )
plt.subplot(2,2,2)
plt.plot(df['annual_rent_usd'] )
plt.subplot(2,2,3)
plt.plot(df['bedrooms'] )
plt.subplot(2,2,4)
plt.plot(df['community'] )

# %%
plt.scatter(df['annual_rent_usd'],df['area_m2'])

# %%
plt.hist(df['bedrooms'],bins=3, color='skyblue')
# Out:
# (array([8037., 9617., 7346.]),
#  array([0., 2., 4., 6.]),
#  <BarContainer object of 3 artists>)

# %%
# Out:
#             id date_listed              community            zone       lat  \
# 24995  R024996  2023-02-19              Expo City     Dubai South  24.97266
# 24996  R024997  2023-04-01  Dubai Investment Park             DIP  25.00383
# 24997  R024998  2024-05-26         Emirates Hills  Emirates Hills  25.04242
# 24998  R024999  2026-02-21                 La Mer        Jumeirah  25.22381
# 24999  R025000  2025-10-10         Living Legends       Dubailand  25.08047
#
#             lon property_category property_type  bedrooms  area_sqft  ...  \
# 24995  55.13237         apartment           2BR         2       1283  ...
# 24996  55.18909         apartment        studio         0        347  ...
# 24997  55.15843             villa     4BR_villa         4       3265  ...
# 24998  55.26591             villa     4BR_villa         4       3625  ...
# 24999  55.29660         apartment           2BR         2       1130  ...
#
# ...

# %%
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x16895ad7610>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x16895ad7890>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x16895ad74d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x16895ad7b10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x16895ad7c50>],
#  'means': []}

# %%
df['bedrooms'].mean()
# Out:
# np.float64(2.52184)

# %%
df['bedrooms'].isna()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 24995    False
# 24996    False
# 24997    False
# 24998    False
# 24999    False
# Name: bedrooms, Length: 25000, dtype: bool

# %%
df.describe()
# Out:
#                 lat           lon      bedrooms     area_sqft       area_m2  \
# count  25000.000000  25000.000000  25000.000000  25000.000000  25000.000000
# mean      25.109921     55.249857      2.521840   2212.728320    205.568880
# std        0.093214      0.077189      1.624078   1792.284074    166.508337
# min       24.884760     55.065310      0.000000    300.000000     27.900000
# 25%       25.041645     55.184567      1.000000    791.000000     73.500000
# 50%       25.078900     55.255140      3.000000   1481.000000    137.600000
# 75%       25.198213     55.295203      4.000000   3287.250000    305.425000
# max       25.316160     55.529840      6.000000  11118.000000   1032.900000
#
#        parking_spaces  metro_distance_min  to_burj_khalifa_km     n_cheques  \
# count    25000.000000        25000.000000        25000.000000  25000.000000
# mean         1.896800          118.613280           14.605406      4.259640
# ...

# %%
sns.boxplot(x=df['bedrooms'])
# Out:
# <Axes: xlabel='bedrooms'>

# %%
df.head()
# Out:
#         id date_listed      community           zone       lat       lon  \
# 0  R000001  2024-12-20    Town Square         Nshama  25.02906  55.25610
# 1  R000002  2021-07-06      Expo City    Dubai South  24.96152  55.15759
# 2  R000003  2023-05-10  Palm Jumeirah  Palm Jumeirah  25.10836  55.13304
# 3  R000004  2021-12-30          Deira          Deira  25.28720  55.30205
# 4  R000005  2023-12-08      The Views     The Greens  25.08438  55.18399
#
#   property_category property_type  bedrooms  area_sqft  ...  parking_spaces  \
# 0         apartment           1BR         1        748  ...               1
# 1         apartment           1BR         1       1011  ...               2
# 2         apartment           1BR         1        825  ...               2
# 3         apartment           1BR         1        755  ...               1
# 4         apartment           1BR         1        746  ...               1
#
# ...

# %% [markdown]
# remove karna  - ,community ,	metro_station ,contract_type

# %%
# Sahi tarika columns ko drop karne ka
df_clean = df.drop(columns=['community', 'property_category', 'contract_type', 'metro_station' ,'zone' , 'property_type' , 'furnishing' ,'view' ,'date_listed' ,'chiller_included' , 'metro_line'])

df_clean
# Out:
#             id       lat       lon  bedrooms  area_sqft  area_m2  \
# 0      R000001  25.02906  55.25610         1        748     69.5
# 1      R000002  24.96152  55.15759         1       1011     93.9
# 2      R000003  25.10836  55.13304         1        825     76.6
# 3      R000004  25.28720  55.30205         1        755     70.1
# 4      R000005  25.08438  55.18399         1        746     69.3
# ...        ...       ...       ...       ...        ...      ...
# 24995  R024996  24.97266  55.13237         2       1283    119.2
# 24996  R024997  25.00383  55.18909         0        347     32.2
# 24997  R024998  25.04242  55.15843         4       3265    303.3
# 24998  R024999  25.22381  55.26591         4       3625    336.8
# 24999  R025000  25.08047  55.29660         2       1130    105.0
#
#        parking_spaces  metro_distance_min  to_burj_khalifa_km  n_cheques  \
# 0                   1                 373               18.79          6
# ...
